# %% [markdown]
# GROUP 8:  Viktoriia Yuzkiv, Sebastien Boxho,Arianna Michelangelo
#
# This notebook includes the pipeline to scrape Booking.com listings data and saves the data into a csv file.
#
#
# Cities:
# - Barcelona
# - Marseille
# - Valencia
# - Porto
#
# Dates:
# - MWC Barcelona: 26 - 29 February 2024 (selected period: 23 Feb - 3 Mar)
# - The second period: March 8 - 17th

# %% [markdown]
# ## Import libraries

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
from selenium.common.exceptions import NoSuchElementException

import time
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ## Open and scrape Booking

# %%
# Path to your geckodriver file - please change to your path before running the code
geko_path = './geckodriver' 

# Please change to your profile path (if you have one)
profile_path = '/Users/viktoriia/Library/Application Support/Firefox/Profiles/k7kr4dw0.Viktoriia' 

# Booking link
link = 'https://www.booking.com/index.en-gb.html'

# %%
def start_up(link, geko_path, profile_path):
    '''
    Function to set up the browser and open the selected link (usin)
    '''
    if profile_path:
        firefox_options = webdriver.FirefoxOptions()
        firefox_options.add_argument(f'--profile={profile_path}')
        service = Service(geko_path)
        browser = webdriver.Firefox(service=service, options=firefox_options)
    
    else:
        profile = webdriver.FirefoxProfile()
        options = Options()
        options.profile = profile
        service = Service(geko_path)
        browser = webdriver.Firefox(service=service, options=options)
    
    
    # Website address here
    browser.get(link)
    time.sleep(2)  # Adjust sleep time as needed
    
    # Maximize the browser window for full screen
    browser.maximize_window()
    
    if not profile_path:
        # Click on "Accept cookies"
        browser.find_element(by='xpath',value='//button[@id="onetrust-accept-btn-handler"]').click()
    
    return browser

# %%
def check_and_click(browser, path, type):
    '''
    Function that checks whether the object is clickable and, if so, clicks on
    it. If not, waits one second and tries again. After 3 seconds of waiting, it doesn't try anymore.
    '''
    start_time = time.time()  # Record the start time
    while True:
        try:
            if type == "xpath":
                browser.find_element('xpath',path).click()
                return "Clicked!"  # Element found and clicked successfully
            elif type == "css":
                browser.find_element('css selector', path).click() 
                return "Clicked!"  # Element found and clicked successfully
        except NoSuchElementException:
            pass  # Continue if element not found
        except Exception as e:
            print(f"An error occurred: {e}")
            return False  # Other unexpected errors

        time.sleep(1)
        elapsed_time = time.time() - start_time
        if elapsed_time >= 3:
            # print("* The element was not found in the page. *")
            return None            
            
            
            
def check_obscures(browser, xpath, type):
    '''
    Function that checks whether the object is being "obscured" by any element so
    that it is not clickable. Important: if True, the object is going to be clicked!
    '''
    try:
        if type == "xpath":
            browser.find_element('xpath',xpath).click()
        elif type == "id":
            browser.find_element('id',xpath).click()
        elif type == "css":
            browser.find_element('css selector',xpath).click()
        elif type == "class":
            browser.find_element('class name',xpath).click()
        elif type == "link":
            browser.find_element('link text',xpath).click()
    except (ElementClickInterceptedException, NoSuchElementException, StaleElementReferenceException) as e:
        print(e)
        return False
    return True

# %%
def select_place(browser, place):
    '''
    Function to choose a place of interest
    '''
    search1 = browser.find_element(by='xpath',value='//*[@id=":re:"]')
    search1.send_keys(place)
    time.sleep(2)
    
    
def select_dates(browser, start_date, end_date, month = 'enero 2024'):
    '''
    Function to choose dates of interest
    '''
    # Click on the dates filter
    css='button.ebbedaf8ac:nth-child(2) > span:nth-child(1)'
    browser.find_element('css selector',css).click()
    time.sleep(2)
    
    # Open dates filter on the month of interest
    while browser.find_element('xpath','//h3[@class="e1eebb6a1e ee7ec6b631"]').text != month:
        path = '//button[@class="a83ed08757 c21c56c305 f38b6daa18 d691166b09 f671049264 deab83296e f4552b6561 dc72a8413c f073249358"]'
        browser.find_element('xpath',path).click() 
    
    # Get the list of all dates
    path='//div[@id="calendar-searchboxdatepicker"]//table[@class="eb03f3f27f"]//tbody//td[@class="b80d5adb18"]//span[@class="cf06f772fa"]'
    dates = browser.find_elements('xpath',path)
    time.sleep(2)
    for date in dates:
        if date.get_attribute("data-date") == start_date:
            date.click()
        if date.get_attribute("data-date") == end_date:
            date.click()
            break

# %%
def get_number_pages(browser):
    '''
    Function to get total number of pages. 
    '''
    a = browser.find_elements('xpath', '//button[@class="a83ed08757 a2028338ea"]')
    return(int(a[-1].text))


def get_hotels(browser):
    '''
    Functio to get hotels from a page. Returns a pandas dataframe.
    '''
    temp_list = []
    hotel_placeholder =  browser.find_elements('xpath','//div[@class="c066246e13"]')
    
    for hotel in hotel_placeholder:
        hotel_name = hotel.find_element('xpath','.//div[@class="f6431b446c a15b38c233"]').text
        hotel_price = hotel.find_element('xpath','.//span[@class="f6431b446c fbfd7c1165 e84eb96b1f"]').text 
        hotel_link = hotel.find_element('xpath','.//a[@class="a78ca197d0"]').get_attribute('href')
       
        try:
            hotel_description = hotel.find_element('xpath','.//div[@class="abf093bdfe d323a31618"]').text
        except NoSuchElementException:
            hotel_description = np.nan
        
        try:
            hotel_rating = hotel.find_element('xpath','.//div[@class="a3b8729ab1 d86cee9b25"]').text   
        except NoSuchElementException:
            hotel_rating = np.nan
        
        temp_list.append({'name': hotel_name, 'price': hotel_price,
                      'description_short': hotel_description, 'rating': hotel_rating,
                      'url': hotel_link})
    
        print(hotel_name)
        
    return temp_list

# %%
# Change place here or add other places
places = ['Barcelona']   # ['Barcelona', 'Marseille']

# Change dates here
dates = [{'start_date': '2024-03-08', 'end_date': '2024-03-17', 'month': 'March 2024'}]


df = pd.DataFrame(columns = ['place', 'start_date', 'end_date', 'name', 'price', 'description_short', 'rating', 'url'])

for date in dates:
    start_date = date['start_date']
    end_date = date['end_date']
    month = date['month']
    
    for place in places:
        
        # Open home page
        
        # If you have a Firefox profile with ad-blocker, please add your profile_path here.
        # Otherwise, no changes in the code are needed, but the Google pop-up will have to be closed manually.
        browser = start_up(link, geko_path, profile_path=False)
        

        time.sleep(5)
        
        # Check for the pop up on the first page and close it if it appears
        check_and_click(browser, '.f4552b6561', 'css')
         
        # Choose the place
        select_place(browser, place)

        # Choose the dates
        select_dates(browser, start_date, end_date, month)

        # Click on the search button
        my_xpath='/html/body/div[3]/div[2]/div/form/div[1]/div[4]/button/span'
        check_and_click(browser,my_xpath , type='xpath')
        
        time.sleep(3)
        
        # Click on the another pop up
        check_and_click(browser, 'div.cc1b961f14:nth-child(1) > button:nth-child(1)', 'css')
        
        # Get the number of pages
        pages = get_number_pages(browser)
        
        for p in range(pages):
            
            df_temp = pd.DataFrame(get_hotels(browser))
            df_temp['place'] = place
            df_temp['start_date'] = start_date
            df_temp['end_date'] = end_date
            
            df = pd.concat([df, df_temp], ignore_index=True)
            time.sleep(2)
            # Click on the next button
            css= 'div.b16a89683f:nth-child(3) > button:nth-child(1)'
            browser.find_element('css selector',css).click() 
            time.sleep(2)
# Out:
# Duquesa Suites Barcelona
# Sonder Casa Luz
# Very quiet and centric area to enjoy Barcelona
# TWO Hotel Barcelona by Axel 4* Sup- Adults Only
# Sallés Hotel Pere IV
# The Hoxton, Poblenou
# Vincci Bit
# The Streets Apartments Rambla
# Travelodge Barcelona Poblenou
# Hotel America Barcelona
# Four Points by Sheraton Barcelona Diagonal
# Hotel & Spa Villa Olimpica Suites
# Vincci Maritimo
# NH Sants Barcelona
# Catalonia Sagrada Familia
# Barcelonaforrent Urban Town Suites
# Hotel Barcelona Center
# Hostel New York
# Zenit Barcelona
# Hilton Barcelona
# Hostal Boqueria
# RAMBLAS HOTEL powered by Vincci Hoteles
# Catalonia Atenas
# NH Barcelona Diagonal Center
# Acta CITY47
# Hotel Lloret Ramblas
# Hotel Concordia Barcelona
# Leonardo Hotel Barcelona Gran Via
# Occidental Atenea Mar - Adults Only
# ITC Barcelona By Soho Boutique
# Hesperia Barcelona Presidente
# Leonardo Royal Hotel Barcelona Fira
# Acacia Suite
# Gran Hotel Havana 4Sup by Escampa Hotels
# Nice apartment BCN two rooms wifi
# Radisson Blu 1882 Hotel, Barcelona Sagrada Familia
# NH Barcelona Les Corts
# Suites Avenue
# Gallery Hotel
# Upper Diagonal
# Ofelias Hotel 4Sup by Bondia Hotel Group
# Catalonia Passeig de Gràcia 4* Sup
# Ako Suites Hotel
# The White Flats Les Corts
# Axel Hotel Barcelona & Urban Spa- Adults Only
# Casa Elliot by Bondia Hotel Group
# AC Hotel Barcelona Fórum by Marriott
# Bonanova Suite
# Vincci Mae
# The Social Hub Barcelona Poblenou
# Laramond Barcelona Rooms
# Hotel Market
# Vincci Gala
# Hostal Las Flores Ramblas
# Pensión Villanueva
# NH Collection Barcelona Constanza
# Hotel Nuevo Triunfo
# Sunny 2-Bedroom Apartment City Beach
# AC Hotel Irla by Marriott
# Catalonia Square 4* Sup
# Holiday Inn Express Barcelona City 22@, an IHG Hotel
# Motel One Barcelona-Ciutadella
# NH Barcelona Entenza
# Hostal Barcelona Travel
# Hotel Ronda Lesseps
# Stylish Apartments
# Mercedes Heritage Apartments
# Youth Hostel - Central and Basic Universitat
# Hotel Medicis
# Ilunion Almirante
# Pol & Grace Hotel
# Hotel Arts Barcelona
# Sunotel Club Central
# Silken Sant Gervasi
# Room Mate Anna
# Aparthotel Senator Barcelona
# Cami Gallery Barcelona
# Catalonia Albeniz
# Torre Melina, a Gran Meliá Hotel
# Barceló Sants
# Sercotel Caspe
# Hotel Casa Fuster G.L Monumento
# NH Barcelona Stadium
# Hotel Best Front Maritim
# Isabella's House
# Suite Home Sagrada Familia
# Hotel Boutique Mirlo Barcelona
# AC Hotel Sants by Marriott
# Leonardo Boutique Hotel Barcelona Sagrada Familia
# Habitación triple/Ramblas
# Lodging Apartments City Center-Eixample
# Barcelona Apartment Republica
# Sixtytwo Hotel
# Petit Palace Boqueria Garden
# Aparthotel Napols - Abapart
# The Moods Oasis
# Andante Hotel
# Barcelona House
# Oriente Atiram
# Catalonia Park Putxet
# Guitart Grand Passage
# Mesón Castilla Atiram Hotels
# Hostalet de Barcelona
# Ilunion Auditori
# Catalonia Gracia
# You Stylish Diagonal Apartments
# Casa Gracia
# Hostal Benidorm
# Capri by Fraser Barcelona
# BARCELONA GOTIC Guesthouse
# Alexandra Barcelona Hotel, Curio Collection by Hilton
# Hotel Villa Emilia
# Hotel Nouvel
# Pestana Arena Barcelona
# Ocean Drive Barcelona
# Tres Torres Atiram Hotels
# Hotel Raval House
# Hotel Serhs Rivoli Rambla
# Catalonia Avinyo
# Monument Hotel
# Casa Lit Barcelona by Ona
# Leonardo Hotel Barcelona Las Ramblas
# Fewdays Barcelona Apartments
# Occidental Barcelona 1929
# Eurohotel Diagonal Port
# Apartments Sixtyfour
# Hotel Cantón
# Aparthotel Allada 3*
# Hostal Operaramblas
# Mosaic Barcelona by Ona
# Hotel Ramblas Internacional
# Sunotel Central
# Ciudad Condal Hostal - Paseo de Gracia
# Suite Place Barcelona Còrsega
# 1881 Barcelona Gran Rosellon Hotel
# Chic & Basic Born Boutique Hotel
# AC Hotel Victoria Suites by Marriott
# Suites Center Barcelona
# Iberostar Selection Paseo de Gracia 4 Sup
# Catalonia Rigoletto
# Central and Basic Solarium HOSTEL
# Atlantis by Atbcn
# Blanc Guest House
# Montserrat Apartments by gaiarooms
# Room Mate Pau
# Fira Apartments by gaiarooms
# Quartprimera Apartments
# Hotel Condal
# Blue Barcelona
# Alma Barcelona GL
# Hotel Serhs Carlit
# Alma Barcelona GL
# Hotel Serhs Carlit
# Barcelona Apartment Gran de Gràcia
# BYPILLOW House
# Lodging Apartments Liceu G2
# Hostal Conde Güell
# Catalonia Ramblas 4* Sup
# Room Mate Gerard
# Catalonia Eixample 1864
# 08028 Apartments
# Europark
# LetsGo Paseo de Gracia
# Catalonia Born
# U232 Hotel
# Catalonia Gran Via BCN
# Wilson Boutique Hotel
# Hotel El Call
# Catalonia Portal de l'Angel
# You Stylish City Center Apartments
# Fisa Rentals Gran Via Apartments
# BYPILLOW Wander
# Central Suites Barcelona
# NH Barcelona Eixample
# Generator Barcelona
# Minutes to the beach, near Convention Centre and free parking
# Hotel Acta Azul Barcelona
# Lodging Apartments Forum 15 - Barcelona Forum apartment with sea view
# Acta Atrium Palace
# DreamKeys Barcelona City
# Golden Hotel Barcelona
# Abba Garden
# AC Hotel Diagonal L'Illa by Marriott
# Chic & Basic Velvet
# Aparthotel Augusta
# Lugaris Beach Apartments
# HG City Suites Barcelona
# Rooms Nueva Valencia
# Sercotel Amister Art Hotel Barcelona
# Chi
# Barceló Raval
# Room Mate Carla
# Hostal Balkonis
# Four Petals Barcelona Boutique Apartments
# ICON Bcn
# INNSiDE by Meliá Barcelona Apolo
# Feelathome Plaza Apartments
# Flor Parks
# Catalonia Magdalenes
# Inside Barcelona Apartments Esparteria
# Hotel BESTPRICE Diagonal
# Hotel Transit
# Picasso Suites
# Acevi Villarroel
# Occidental Diagonal 414
# BarcelonaForRent Tucson Suites
# Barcelonaforrent The Claris Suites
# Hotel Balmoral
# Hostal Felipe 2
# BizFlats Eixample Apartments
# Habitaciones Rambla Catalunya
# Grums Hotel & Spa
# Hotel Barcelona Universal
# BarcelonaForRent Vila Olimpica Pool Suites
# Relax
# Silken Ramblas
# Arc La Rambla
# Arenas Atiram Hotels
# Hilton Diagonal Mar Barcelona
# Hotel Barcelona Condal Mar Affiliated by Meliá
# Hostal Parisien Las Ramblas
# Dalia Ramblas
# Hotel Serhs del Port
# Hotel Vilamarí
# Negresco Princess 4* Sup
# Aparthotel Bcn Montjuic
# BYPILLOW Ramblas
# Eric Vökel Boutique Apartments - Gran Vía Suites
# Inside Barcelona Apartments Sants
# Royal Ramblas
# Apartments Sata Park Guell Area
# Hostel Friends Barcelona
# Grupotel Gravina
# BYPILLOW Mothern
# Catalonia Mikado
# Sunotel Aston
# Ola Living Hostal Diagonal
# Hotel Constanza
# NH Collection Barcelona Podium
# Hostal La Terrassa
# Colors
# Ibis Barcelona Meridiana
# Hotel Rec Barcelona - Adults Only
# Sunotel Junior
# Hostal Barcelona
# Hotel Jazz
# Catalonia Park Güell
# Paral·lel
# Catalonia Roma
# Catalonia Catedral
# Rooms Nuevo Roger
# Catalunya
# Cosmopolitan Boutique Rambla
# B Hotel
# Apartments Sata Sagrada Familia Area
# Catalonia Plaza Catalunya
# Close to Passeig de Gracia
# Best Western Plus Hotel Alfa Aeropuerto
# Habitat Apartments Blanca
# Kimpton Vividora Hotel, an IHG Hotel
# Catalonia Castellnou
# Caledonian
# Apart-Suites Hostemplo
# Hotel Soho
# Catalonia Barcelona Plaza
# Catalonia Port
# Casa Lirio
# Niu Barcelona Hotel
# Ola Living Born
# Catalonia La Maquinista
# Hotel Rialto
# 360 Hostel Borne
# Exe Cristal Palace
# Melia Barcelona Sarriá
# Praktik Bakery
# Sonder La Casa del Sol
# Sonder La Casa del Sol
# Hotel 54 Barceloneta
# Ola Living Vidreria
# May Ramblas Hotel
# Yurbban Passage Hotel & Spa
# Parque güell
# Le Palacete powered by Sonder
# Olivia Plaza Hotel
# Hotel El Palace Barcelona
# Lugaris Rambla Apartments
# HCC Regente
# SmartRoom Barcelona
# DO Plaça Reial powered by Sonder
# Praktik Garden
# Àmfores Boutique Guest House
# Vi l'Art Wine Lodge
# Apartamentos Calvet
# Hotel del Mar
# BcnStop Sagrada Familia
# La Casa de Antonio Boutique Rooms
# Hostal Girona
# Hotel Cortes Rambla
# Pierre & Vacances Barcelona Sants
# Piquer con Terraza
# Hotel SB Glow Sup
# Grupotel Gran Via 678
# B-Garden BCN
# Urgel habitaciones
# Inside Barcelona Apartments Princep
# Seventy Barcelona
# Via Sants Hotel Barcelona, Tapestry Collection By Hilton
# Habitat Apartments Cool Jazz
# Diagonal House Hostel
# Le Meridien Barcelona
# Barcelona Hotel Colonial
# Express by gaiarooms
# Mihlton Barcelona Boutique B&B
# Rooms in the center of Barcelona
# Sir Victor Hotel, part of Sircle Collection
# Acta Splendid
# Feelathome Poblenou Beach Apartments
# Hotel Miramar Barcelona GL
# París Habitaciones
# NH Collection Barcelona Gran Hotel Calderon
# Ola Living MACBA
# ME Barcelona
# Habitat Apartments Hot Jazz
# BBarcelona Central Boutique Apartments
# Tibidabo Apartments
# BcnStop Parc Güell
# Petit Palace Museum
# Casa Barcelo Hostel Barcelona
# Musik Boutique Hotel
# The Barcelona EDITION
# Hotel Well and Come
# Aspasios Rambla Catalunya Suites
# Umma Barcelona B&B Boutique
# numa l Roca Rooms & Apartments
# Happy People Gaudi Sant Pau Apartments
# Home to Home Barcelona
# Hotel Inglés
# Hotel Santa Marta
# Boutique Hostemplo Sagrada Familia
# Evenia Rocafort
# Hotel Alguer Camp Nou
# Condes de Barcelona
# Charmsuites Paralel
# Ilunion Les Corts Spa
# Sercotel Hotel Rosellon
# Alba Hotel
# ABAL554 - Azotea exclusiva del centro de la ciudad
# Cosmo Apartments Passeig de Gràcia
# Estudio para parejas
# Aspasios Garden Apartments
# Aparthotel Mariano Cubi Barcelona
# BUHO Boutique Rooms
# Apartments Sata Olimpic Village Area
# Suitur apartamento floridablanca barcelona
# Espais Blaus Apartments
# Rooms Arago
# Hostal Bcn 46
# Inside Barcelona Apartments Salva
# El Avenida Palace
# Apartaments-Hotel Hispanos 7 Suiza
# H10 Port Vell 4* Sup
# Midtown Apartments
# Aspasios Las Ramblas Apartments
# Sonder Paseo de Gracia
# BBarcelona Clot Apartments
# Hotel Ciutadella Barcelona
# Rufus Port Forum
# La Mare by The Streets
# AinB Sagrada Familia Apartments
# Alos Apartments Paseo de Gracia-Diagonal
# Fontanella By BCN URBAN Rooms
# Cosmo Apartments Sants
# Hotel Suizo
# Plaza Goya Rooms
# Hostemplo Sagrada Familia
# The One Barcelona GL
# Jardinets De Gràcia by The 5ve Soul
# Renaissance Barcelona Hotel
# Praktik Èssens
# Duquesa Suites Barcelona
# ibis Styles Barcelona City Bogatell
# B&B Boutique Ca La Maria
# ABaC Restaurant Hotel Barcelona GL Monumento
# Sensation Authentic Gràcia
# numa I Brio
# Weflating Suites Sant Antoni Market
# Jacobs Inn Barcelona
# Happy People Ramblas Harbour Apartments
# Arya Stadium Hotel
# chic&basic Reding
# Arcelon Hotel! New Opening! Nueva apertura 2023!
# BBarcelona Còrsega Flats
# Apartaments Independencia
# Hostal Drassanes
# Vasanta powered by Sonder
# Weflating City Center
# Gran Vía by The Streets
# Boat Hotel Barcelona
# Sensation Sagrada Familia
# Hotel SOFIA Barcelona, in The Unbound Collection by Hyatt
# Aparthotel Rambla108
# Aparthotel Rambla108
# Colom Apartments
# Hotel Glòries
# Valencia 3
# Stay U-nique Apartments Rossello
# Attica 21 Barcelona Mar
# SmartRental Barcelona Ramblas
# Bonavista Apartments - Virreina
# Sant Antoni Market
# SPACIOUS YACHT HOTEL BARCELONA CITY CENTER 5 CABINs
# Stay U-nique Apartments Rambla Catalunya
# AinB Picasso-Corders Apartments
# Casa Bella Gracia by Aspasios
# Habitat Apartments ADN
# Melia Barcelona Sky 4* Sup
# BruStar Gotic-Centric
# The Level at Melia Barcelona Sky
# Southern Cross
# La França Travellers Adults Only
# Yate Hotel STV
# LucasLand Apartments Barcelona
# Radas
# Praktik Rambla
# Hostal Ramos
# Barcelona City North Hostal
# Hotel Lyon
# Barcelona Princess
# 017 New of love 3 1
# Habitación doble en Eixample
# Spot Smart Nomad
# By Paseo de Gracia Rooms
# Sunny rooms bcn
# Fashion House
# Casa Gracia Apartments
# APBCN Eixample Center
# Mr. Serrano Apartments
# Tendency Apartments 7
# Happy People Plaza España Apartments
# Hostal Hera
# Durlet Beach Apartments
# Eixmaple Apartments
# Rambla de Mar Apartments
# Casagrand Luxury Suites
# Boat Accommodations Barcelona
# Hostal Martinval
# TOC Hostel Barcelona
# Ant Hostel Barcelona
# Barcelona City Hotel
# Palau de la Musica Apartments
# Habitat Apartments Grace
# Hostal Argo
# Hotel SB Diagonal Zero 4 Sup
# Best Western Premier Hotel Dante
# AB Paral·lel Spacious Apartments
# Barcelona City Apartment
# H10 Art Gallery 4* Sup
# Hostal River
# Bright & Breezy
# Hotel Casa Sagnier
# El Palauet Royal Suites
# Barcelona City Centre Hostal
# Barnapartments Basic Gracia
# Tendency Apartments 5
# El Jardi
# Barcelona City Rooms
# Sagrada Familia
# Suite Gracia Barcelona
# Tendency Apartments 9
# MH Apartments Liceo
# Villa Sagrada
# Lumine Luxury Suites by gaiarooms
# Room018BCN
# !!Boat with AC in Port Forum 2 Bikes Included!!
# H10 Casa Mimosa 4* Sup
# Casa Balmes
# Rooms Sepulveda
# LB Nice Apartment Sagrada Familia
# Dream Gracia Apartments
# Chic & Basic Lemon Boutique Hotel
# Cosmo Suite Penthouse
# Mellow Barcelona
# limehome Barcelona Carrer de Besalú 82
# numa I Seda Apartments
# Hotel Gótico
# Apartment Eixample Comfort
# My Space Barcelona Executive Apartments Center
# ClassBedroom Barcelona Beach Apartments
# Labtwentytwo Barcelona, a Tribute Portfolio Hotel
# My Space Barcelona Charming Apartment in the Heart of Gracia
# Barrio Gotico Apartments Ferran
# Gran Hotel Barcino
# Casa Vaganto
# Duquesa de Cardona 4* Sup
# Apartaments Marina - Abapart
# Descanso Náutico
# Barnapartments Raval
# Bird House
# Heart of Barcelona Rooms
# limehome Barcelona Carrer de Fontcoberta - Digital Access
# Yurbban Ramblas Boutique Hotel
# Aparthotel Atenea Barcelona
# By Port Vell Rooms
# Nice room By Eixample
# Hotel Continental Barcelona
# Hotel BESTPRICE Gracia
# Sepulveda 1
# Cute Apartment in Sants Station with HBO & Alexa & AC
# H La Paloma Adults Only
# Sweet Inn - Sepulveda
# Hotel Oasis
# 2 BDR EIXAMPLE APARTMENT
# Aparthotel Bertrán
# Rosello 3
# Beautiful Triple room with private bathroom in Gothic
# EasySleep Eixample
# Mambo Tango
# Apartamento Barcelona
# Pensión San Ramón
# Catalonia Diagonal Centro
# By Born Rooms
# Hotel Lugano Barcelona
# The Hotel 592 - Adults Only
# Alcam Baro 22
# Hostal Lausanne
# Ramblas Hotel
# Hostal Sans
# Suite Miro Eixample Barcelona
# Nobu Hotel Barcelona
# Bedcelona Hostel
# Eixample private rooms
# Sweet Inn - Avenida Roma
# Relax SEA
# Habitación doble con baño privado en Barcelona
# Good-Home Paseo de Gracia
# Port VII Apt centrico acogedor w balcon 23
# Urban Loft Barcelona Diagonal super ubicación wifi
# El Caliu
# EasySleep Gaudi Terrace
# Lodging Apartments Gracia 2
# Apartment Vila Olímpica Barcelona next to beach & garden
# Be Barcelona Eixample Urquinaona II
# Hotel Pulitzer Barcelona
# Rosello 2
# Fantastic apartment near Plaça Francesc Macia in L'Eixample Esquerra
# Mandarin Oriental, Barcelona
# Barcelona - Eixample Entresuelo
# Fira Guest House
# DIAGONAL/PASEO DE GRACIA 4 PAX
# By Rambla de Catalunya Rooms
# Lovely wooden boat in Port forum, with AC and two bikes.
# The best room in the Gothic quarter with suite bathroom
# Rooms in Gothic
# Beautiful studio in el Born
# Apart céntrico con terraza en Gracia
# Stylish Apartment with Terrace for Couple or Family
# Traditional rooms in Eixample
# ChicStays Apartment Vila Olímpica
# CIUDADELA PARK 1
# Ideal Youth Hostel
# La Maison de Barcelone
# Enjoy Apartments Calabria
# Apartaments Clot-Sant Martí
# Sunny 2-Bedroom Apartment City Beach
# Bed&BCN Arquimedes Barcelona
# L'Olivera Casa Rural
# Coronado
# Friendly Rentals Santa Monica
# Limonaia
# Port I Espectacular apartament con terraza
# Stay Barcelona Charming Gracia
# Permar Sagrada Familia
# numa I Colmena Apartments
# ibis Styles Barcelona Centre
# Sagrada Familia Gaudi
# Port V Apart centrico con estilo 21
# Port V Apart centrico con estilo 21
# Apartment Barcelona Rentals - Sarria Apartments Near Center
# Central Apartments Barcelona
# Apartamento central y grande en Barcelona
# Comfort Home Playa Poblenou
# Sagrada Familia View Apartment
# Mr Born
# Charming Flats by Aspasios
# Flat Eixample Napoles/Apartment
# Cozy Apartment Les Corts
# Abba Rambla Hotel
# Allegro Barcelona
# Permar Barceloneta
# 2 bedroom Duplex apartment with balcony 4-3
# Habitat Apartments Plaza España Urban
# Beautiful y Luxury Apartment centrallylocated
# Amazing sunset views in the Mediterranean Apart/
# Central Corner of Love with terrace
# Casanova Apartments by Olala Homes
# Magic Place
# BCN Rambla Catalunya Apartments
# chic&basic Habana Hoose
# Trip Barcelona Spain
# Hostal Elkano
# Som Nit Port Vell
# Hostal LK Barcelona
# CAMP NOU & FiRA BUSINESS LOFTS
# Sant Antoni 3 - Downtown Barcelona & Modern
# Cool&colorful Centric Apartment
# Oasis Sagrada Familia
# Diagonal 1
# Barrio Gotico Apartments Escudellers
# Bed&BCN Diagonal 1
# Teatro Miro Apartment
# Rocafort in Eixample
# Anais Apartments by gaiarooms
# Yach boat Experience
# numa I Lustre Apartments
# Stay Barcelona Borne Apartment
# Stay Barcelona Vila de Gracia
# Lodging Apartments Illa Diagonal
# Private rooms in Gothic
# Rambla Poblenou&Mar Bella Beach
# Ronda Sant Pere - Private City Center 1-Bedroom Suite
# Barcelona4Seasons - Sagrada Familia
# Sant Pau Ramblas Apartments Serennia
# Stay Barcelona Sant Antoni
# By Liceu Rooms
# Hotel Palermo
# Private room By BCN Center
# Key Sagrada Familia - Carrer Del Clot
# Bcn Friendly Parlament
# Alcam Galileu
# Líbere Barcelona Sant Antoni
# Private Room Gothic Quarter
# Beautiful & quiet 2BR flat with terrace
# Jie Apartment
# Modern Flat next to Bogatell beach
# Beautiful and best location apt
# Lodging Apartments Barceloneta Beach Studio P2
# Rosello 1
# Modern and bright apartment in Eixample 5-2
# Nuevo Aragó Habitaciones
# Gracia Barcelona Apartment
# Exclusive 2 bedroom apartment in the city center
# Homenfun Barcelona Guinardó Hospital Sant Pau
# Wow Hostel Barcelona
# Gracia15
# Claris Apartments
# Central Station Hostel Barcelona
# Hotel Best 4 Barcelona
# Gracia14
# Serras Barcelona
# BarcelonaForRent The Central Place
# Consell Cent apartment I 3 dormitorios Eixample
# DB Nice apartment Sagrada Familia
# Lodging Apartments Beach Studio P1
# Private terrace at Sagrada Familia
# Llibreteria
# Angeles Terraza
# SAGRADA FAMILIA VIEWS Nos preocupa su seguridad
# By La Boqueria Rooms
# Lodging Apartments Barceloneta Beach Studio 42
# Fisa Rentals Les Corts Apartments
# AB Poble Sec Apartment
# Eixample 7
# The Barcelona Centric APT
# Hostal Mont Thabor
# Enjoybcn Gaudi Apartments
# Modern and bright apartment in Eixample 1-2
# The Vintage Rentals
# Apartment close to Diagonal Beach
# W Barcelona
# Barcelona4Seasons II
# GuestReady - Charming simplicity near Casa Milà
# homeinnbcn
# Spectacular Five Senses Mallorca Apartment
# limehome Barcelona Rector Triadó
# Vale Beach
# Ibis Barcelona Centro (Sagrada Familia)
# Valencia 455
# Apartamento soleado en Barcelona city
# Cozy Studio with Amazing Terrace near Plaza España
# Enjoybcn Patio de Gracia
# Piso Zona Plaza España, junto a Montjuic,
# Sonder Casa Luz
# Barcelona - Sagrada Familia
# MR Patio
# Stay Barcelona Gracia Apartments
# 2 bedroom with balcony in Eixample 1-1
# Wonderful 2-bd apart with balcony Plaza Cataluña
# Parc Güell 2 1
# Sweet Inn - Verdi
# L'alzina Apartment
# Céntrico apartamento
# Luxury 1BR with Patio near the Beach
# Girona 108
# Stay Barcelona Sant Martí
# Lodging Apartments Barceloneta Beach Studio 32
# Casa familiar con piscina
# Luxury Loft with A Pool
# Classbedroom Park Güell Apartment
# Lodging Apartments Barceloneta Beach Studio 31
# Catedral Bas Apartments by Aspasios
# Key Sagrada Familia / MARINA 223
# GuestReady - Bright home near Montjuïc
# Barcelona - Eixample PB
# Barcelona - Poble Nou
# Family apartment Forum
# Via Augusta
# Bed&BCN Diagonal 5
# Stay U-nique Apartments Taulat
# LUXURY FLAT, 3 BEDROOMS, 2 BATHROOMS AND SWIMMING POOL NEXT TO THE BEACH!!
# Enjoybcn Miro Apartments
# 1208 - EXCLUSIVE DESIGN APARTMENT
# Enjoybcn Fira Apartment
# Luxury MR Born
# Barcelona - Eixample 1A
# Murillo 18
# Cozy place next to Park Güell
# Consell Cent Apartment II 3 domitorios Eixample
# Belleview Villa
# BizFlats Garden House
# Stay Barcelona Plaza España Fira
# Lodging Apartments Beach Studio 41
# White penthouse
# Eixample12
# YACHT 20Metros
# Modern apartment close to the Camp Nou Stadium
# Stay Barcelona Sagrada Familia
# Amazing boat to sleep in Barcelona
# Bed&BCN Diagonal 6
# Private rooms in Born
# Sweet home
# +25Y ONLY, Family flat near the beach
# White Apartment Barcelona
# Urquinaona Rooms
# Stay Barcelona Maragall
# Auditori Barcelona
# Bed&BCN Diagonal 4
# BARCELONA CENTRO SAGRADA FAMILIA
# Autèntic Barcelona Monumental
# Port VI Apart céntrico ideal familias 22
# Ondina Suites Sagrada Familia
# Breathtaking Penthouse in Eixample
# GuestReady - Paris Street in Barcelona Heart
# Acogedor apartamento en Sagrada Familia
# Barco KMP
# By Born & Gothic Rooms
# Bright and modern Duplex with terrace in Eixample district P1
# numa I Boqueria Apartments
# Sagrada Familia Avenida Gaudi Views&cozy Lounge
# Port III Apart céntrico ideal familias 11
# ClassBedroom Port Ramblas
# Navas 2
# Uma Suites Sagrada Familia
# 2 bedroom with balcony in Eixample 4-2
# Forum Benevent
# Comfortable 3BD in Poblenou next to the beach!
# Central and Elegant 4 Bedroom by Placa Catalunya
# Cozy and central apartment
# BarcelonaForRent Sant Pau Barcelona Suites
# Coqueto alojamiento cercano a la Sagrada Familia
# Autèntic Eixample Barcelona
# MR BORN
# Exquisite and Modern Paradise w Private Terrace and City Center
# Beautiful apart in Las Ramblas
# Modern and bright apartment in Eixample 2-1
# Sarria Attic
# Apartamento Sagrada Familia Castillejos
# Hotel Midmost by Majestic Hotel Group
# Lovely Apartment in Plaza España - Fira Montjuïc
# Habitaciones luminosas
# Hostourist@Bcn Rosalia Sagrada Familia
# Be Barcelona Eixample Universidad
# Centric 2bedroom in Las Ramblas 3 1A
# Bright and modern Duplex with terrace in Eixample district P2
# Sagrada Familia- Fantastic Bold Catalan 3 Bedroom Balcony
# Modernist and Luxurious flat - Casa de Flor
# Hostourist@Bcn Centric Eixample
# MR Peblenou
# Stay Barcelona Rossello
# Hostourist@Bcn Apartamento Monumental
# Pl Universitat Bright and cozy 2BD - 2BTH
# Kronos on the Beach suite 3
# Modern and bright apartment in Eixample 5-1
# Elegant 3-bedroom Apartment in the Heart of BCN
# LetsGo Diagonal Avenue Apartment
# Kronos on the beach Suite 4
# Letsgo Camp Nou Apartment
# Hostal Goya
# Ronda Sant Pere
# HOSTAL BEDMATES
# Modern stylish 3 bedroom Arco de Triunfo
# Hostourist@Bcn-Duplex Style in Gracia. Downstair
# 3BD with private terrace right by Sagrada Familia
# Stylish and centric 2-bedroom apartment in Eixample &Terrace P2
# @Hostourist-Bcn Apartamento Fira Plaza España
# Sagrada Familia Butterfly
# LetsGo Sagrada Familia Penthouse
# Kronos on the beach Suite 2
# Spacious & Comfortable flat in centric Eixample
# 5-bed apartment in the heart of the city
# Poblenou renovated 3BD next to the beach
# Yacht in Barcelona
# Be Barcelona Eixample Arco del Triunfo
# Elegant 4 Bedroom by Plaza Catalunya
# 3-bedroom penthouse with terrace in Eixample
# Centric 3bedroom in Las Ramblas 2 1B
# BarcelonaForRent Plaza Sagrada Familia Apartment
# Delightfull with terraze 3beds
# Bright and modern 2bedroom in Las Ramblas 2 1A
# Be barcelona arco del triunfo sunny colors 2
# Canela Homes BARCELONA CASP
# LeMar by Aspasios
# Livingstone
# Recently renovated 3 bedrooms in Poble Sec
# Ático en Gràcia
# akad studio 1
# Comfy 4BD-2BTH with terrace in Plaza España
# MotorYacht 21 avec équipage
# Be Barcelona Plaza Catalunya
# The Moods Catedral Hostal Boutique
# HABITACION PARA PAREJA CON BALCON
# 3bedroom Duplex with balcony in plaza Cataluña
# Luxurious apartment for 9 people recently renovated in the center of Barcelona
# Hostal Granvia 628
# Boutique Hotel H10 Montcada
# Gopal-Comfortable Cozy Apartment for Groups in Gracia
# Apartamentos Laforja
# Green House Hotel
# Boat ALOHA (stay and sail)
# 3 APARTMENTS OLYMPIC VILLAGE
# Magnificent Luxury Yacht in Barcelona center
# Stay U-nique Apartments Diagonal
# Casa vacacional en las montañas de BCN
# Can Caldeta - Naturaleza y privacidad en el Montseny
# Romantic In Trendy Gracia
# Aya House
# Hotel Monegal
# Contempory exclusive Sitges area
# Akad Sweet Home
# Studio Hostel
# Casa ARENYS
# BcnStop Sant Pau Suites
# Habitat Apartments Alissia
# 43APAR469- Super Centric Apartment in Barcelona -
# Chic & Basic Zoo
# Hostal Oliveta
# Hostal Colkida
# Precioso Loft Estudio
# The MO GOTIC
# Stay U-nique Apartments Est
# Antiga Casa Buenavista
# Hotel Denit Barcelona
# Majestic Hotel & Spa Barcelona GL
# Sixties Ramblas
# Hotel Royal Passeig de Gracia
# BacHome Gallery B&B
# Pensión Teruel
# Sonder Los Arcos
# "Casa TOLIMA"
# Hotel Casa Bonay
# Paseo de Gracia Bas Apartments by Aspasios
# Atica Apartments - by Weflating
# Casa Trafalgar Barcelona
# Elegant Eixample Apartment nicely decorated
# By Plaza Urquinaona Rooms
# Casp Green House
# Arc House Gracia
# Apartamentos Barcelona - Iberia
# Bed & Art Barcelona
# Central Rooms Barcelona
# By Universitat Rooms
# H10 Urquinaona Plaza
# Apartment Eixample Dret Sagrada Familia by Interhome
# Lovely apartment with a terrace
# 1314 -AB Passeig de Gràcia Penthouse
# Next to Paseo de Gracia Rooms
# ApartEasy - Lightly, central and quiet apartment
# Leevin Student Barcelona
# Hotel Roger de Llúria
# H10 Madison 4* Sup
# By Plaza Real Rooms
# Nice room close to Sagrada Familia
# Chic Apartments Barcelona
# Homenfun Barcelona Sagrada Familia Lepanto
# Hotel Indigo Barcelona - Plaza Catalunya 4Sup, an IHG Hotel
# Homenfun Barcelona Park Güell
# MUN21 · MUN21 - Apartment with balcony Sagrada Familia
# The MO House
# Citytrip Poble Nou Beach
# 51NO527 - Bright 1bed flat in Poble Sec
# BCN Condal Hostal
# Inside Barcelona Apartments Mercat
# Apartment Gracia Torrijos by Interhome
# Habitat Apartments Ribes
# BacHome Terrace B&B
# Sweet Inn - Palau
# Pedrera - Gràcia
# Eco Boutique Hostal Grau
# MERCE APARTMENT FORUM BARCELONA
# Stay U-nique Apartments Venecuela
# Stay U-nique Apartments Torre d'En Damians II
# Homenfun Barcelona paseo San Juan
# Hostal MiMi Las Ramblas
# Hostal BCN Ramblas
# No Limit Barcelona Central
# Click&Flat Sugranyes
# Stay U-nique Apartments Villarroel
# Born Barcelona Hostel
# SibsBcn COLISEUM - Cozy and Central
# Bcn Centric Rooms
# Hotel 1898
# Rooms By BCN Cathedral
# AB Gracia Sant Salvador
# Apartment Poble Nou
# By La Pedrera - Diagonal Rooms
# Stay U-nique Apartments Gaudi II
# Guest House Barcelona Bruc
# Apartamento Joel
# Homenfun Barcelona Gracia
# Yacht Experience Barcelona
# Habitat Apartments Alaia
# Hostal Laia by gaiarooms
# AinB B&B Eixample-Muntaner
# Gran Hotel La Florida G.L Monumento
# Casa Cosi Sant Antoni
# Maldà Singular Hotel
# MAB2 · MAB2 - Apt at street level with private terrace
# Sweet Inn - Carrer Girona
# ClassBedroom Gaudí Apartments
# Lovly Rooms
# DestinationBCN - Universitat Rooms
# Mediterranean Barcelona Apartments
# Hostal Aslyp 114
# Almanac Barcelona
# AB Poble Nou Venero
# Stay U-nique Apartments GranDeGracia
# Aspasios Sagrada Familia Apartments
# Meeting Point Hostels
# BYPILLOW Twenty
# Olivia Balmes Hotel
# Safestay Barcelona Passeig de Gràcia
# ClassBedroom Gothic Ramblas Apartments
# Stay U-nique Apartments Pou II
# AB Park Güell-Gaudi
# Hip Karma Hostel
# AB Paral·lel Apartments
# You Stylish Sagrada Familia Apartments
# Click&Flat Seneca Suites
# Penthouse Pza España - 4th Floor
# Port Forum Apartments by Olala Homes
# Crysoyle Apartment Barcelona Next to Camp Nou
# Cozy Apartament in the center
# Cozy near the Barcelona Camp Nou Stadium
# NEW Renovated COZY APPARTMENT CENTRIC
# AB Sant Antoni Studio
# GIR1A · GIR1A -Modernist apartment next to Paseo de Gracia
# Wonderful boat for families and friends
# Boat to sleep in Barcelona
# Urban Flats Vallirana
# The Corner Apartments by Aspasios
# Apartamentos Navas 2
# Aspasios Market Balconies
# Stay U-nique Apartments Caminal
# Stay U-nique Apartments Tapioles
# Classbedroom Born Apartments
# Sunny Apartments Barcelona
# Stay U-nique Apartments Travessera II
# Sweet Inn - Carrer Bailen
# Stay U-nique Apartments Rambla Catalunya III
# Apartamento Via Augusta 153
# AB Nou de la Rambla
# Hotel España Ramblas
# Homenfun Barcelona Sagrada Familia Aragón
# Pere Serafi 2 bedroom apartment
# Eric Vökel Boutique Apartments - Sagrada Familia Suites
# Click&Flat Stylish Torrijos
# Stay U-nique Apartments Lope de Vega
# Mini house LOFT 25m2 in Barcelona
# Apartment Sants-Les Corts Galileu by Interhome
# Wittmore Hotel - Adults Only
# AB Marina Apartments
# Lovely & bright Bogatell beach apartment
# Canela Homes BARCELONA FONTANA
# Sweet Inn - Callao
# BBarcelona Montjuïc Apartment
# By Cathedral Rooms
# Apartment Gracia- Providencia by Interhome
# Homenfun Barcelona Sagrada Familia Marina
# By Urquinaona Rooms
# Murmuri Residence Mercader
# Stay U-nique Apartment Ermengarda
# Modern and Chic Apartments in Gracia near Parc Guell
# La Rosa by The Streets
# Alcam Baro SA
# 029 Centric lof 3 3
# Apartment Sants-Montjuic Rambla Badal by Interhome
# Stay U-nique Apartments Sagrada Familia III
# Diagonal Apartments by Olala Homes
# chicStays Apartment Ciutadella Park
# Sweet Inn - Carrer Fira
# Stay U-nique Apartments Sardenya
# Sweet Inn - Eixample

# %%
df.head(10)
# Out:
#        place  start_date    end_date  \
# 0  Barcelona  2024-03-08  2024-03-17
# 1  Barcelona  2024-03-08  2024-03-17
# 2  Barcelona  2024-03-08  2024-03-17
# 3  Barcelona  2024-03-08  2024-03-17
# 4  Barcelona  2024-03-08  2024-03-17
# 5  Barcelona  2024-03-08  2024-03-17
# 6  Barcelona  2024-03-08  2024-03-17
# 7  Barcelona  2024-03-08  2024-03-17
# 8  Barcelona  2024-03-08  2024-03-17
# 9  Barcelona  2024-03-08  2024-03-17
#
#                                               name    price  \
# 0                         Duquesa Suites Barcelona  € 2,003
# 1                                  Sonder Casa Luz  € 1,674
# 2   Very quiet and centric area to enjoy Barcelona    € 383
# 3  TWO Hotel Barcelona by Axel 4* Sup- Adults Only  € 1,361
# 4                             Sallés Hotel Pere IV  € 1,492
# 5                             The Hoxton, Poblenou  € 1,601
# 6                                       Vincci Bit  € 1,649
# 7                    The Streets Apartments Rambla  € 1,834
# 8                    Travelodge Barcelona Poblenou    € 974
# 9                          Hotel America Barcelona  € 1,397
#
#                                description_short rating  \
# 0                                            NaN    8.8
# 1                                            NaN    8.4
# 2                                            NaN    NaN
# 3                                            NaN    8.4
# 4                                            NaN    8.1
# 5                                            NaN    8.7
# 6                                            NaN    8.4
# 7  Entire studio • 1 bathroom • 1 kitchen • 40m²    9.2
# 8                                            NaN    7.3
# 9                                            NaN    8.6
#
#                                                  url
# 0  https://www.booking.com/hotel/es/duquesa-suite...
# 1  https://www.booking.com/hotel/es/casa-luz-barc...
# 2  https://www.booking.com/hotel/es/very-quiet-an...
# 3  https://www.booking.com/hotel/es/two-barcelona...
# 4  https://www.booking.com/hotel/es/pereiv.en-gb....
# 5  https://www.booking.com/hotel/es/the-hoxton-po...
# 6  https://www.booking.com/hotel/es/vincci-bit.en...
# 7  https://www.booking.com/hotel/es/the-streets-a...
# 8  https://www.booking.com/hotel/es/travelodge-ba...
# 9  https://www.booking.com/hotel/es/america-barce...

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'}


# Function to scrape the descriptions using Beautiful Soup
def scrape_description(url):
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status() 
        # time.sleep(0.5)
    except requests.exceptions.RequestException as e:
        print(f"Error processing {url}: {e}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')
    description_tag = soup.find('p', class_='a53cbfa6de b3efd73f69')

    if description_tag:
        return description_tag.get_text(strip=True)
    else:
        print(f"Description tag not found on the page: {url}")
        return None

    

# Set the number of concurrent threads (adjust this based on the processing power of your computer)
num_threads = 16

# Create a ThreadPoolExecutor to run operations in parallel
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Use executor.map to apply the scrape_description function to each URL in parallel
    descriptions = []
    for i, description in enumerate(executor.map(scrape_description, df['url']), start=1):
        descriptions.append(description)
        # Print every 50 link to check the progess of the scraping
        if i % 50 == 0:
            print(f"Scraped {i} links")

# Add  descriptions to the 'description' column in the df
df['description'] = descriptions

# Print count after all threads have completed
print(f"Scraped {len(descriptions)} links")
print("\nDone!\n")
# Out:
# Scraped 50 links
# Scraped 100 links
# Scraped 150 links
# Scraped 200 links
# Scraped 250 links
# Scraped 300 links
# Scraped 350 links
# Error processing https://www.booking.com/hotel/es/apartments-in-barcelona-sagrada-familia.en-gb.html?label=gen173nr-1FCAEoggI46AdICVgEaEaIAQGYAQm4AQfIAQ_YAQHoAQH4AQKIAgGoAgO4AoWluq0GwAIB0gIkMTk3MmE3NzEtNDAxOS00NWUwLWE5ZjEtYWYxNWU2YTMzMTg52AIF4AIB&aid=304142&ucfs=1&arphpl=1&checkin=2024-03-08&checkout=2024-03-17&dest_id=-372490&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=18&hapos=368&sr_order=popularity&srpvid=66eb714cd43f012d&srepoch=1705939689&all_sr_blocks=41093403_91474447_2_0_0&highlighted_blocks=41093403_91474447_2_0_0&matching_block_id=41093403_91474447_2_0_0&sr_pri_blocks=41093403_91474447_2_0_0__191300&from_sustainable_property_sr=1&from=searchresults#hotelTmpl: HTTPSConnectionPool(host='www.booking.com', port=443): Read timed out.
# Scraped 400 links
# Scraped 450 links
# Scraped 500 links
# Scraped 550 links
# Scraped 600 links
# Scraped 650 links
# Scraped 700 links
# Scraped 750 links
# Scraped 800 links
# Scraped 850 links
# Scraped 900 links
# Scraped 950 links
# Scraped 1000 links
# Scraped 1001 links
#
# Done!

# %%
df.head()
# Out:
#        place  start_date    end_date  \
# 0  Barcelona  2024-03-08  2024-03-17
# 1  Barcelona  2024-03-08  2024-03-17
# 2  Barcelona  2024-03-08  2024-03-17
# 3  Barcelona  2024-03-08  2024-03-17
# 4  Barcelona  2024-03-08  2024-03-17
#
#                                               name    price description_short  \
# 0                         Duquesa Suites Barcelona  € 2,003               NaN
# 1                                  Sonder Casa Luz  € 1,674               NaN
# 2   Very quiet and centric area to enjoy Barcelona    € 383               NaN
# 3  TWO Hotel Barcelona by Axel 4* Sup- Adults Only  € 1,361               NaN
# 4                             Sallés Hotel Pere IV  € 1,492               NaN
#
#   rating                                                url  \
# 0    8.8  https://www.booking.com/hotel/es/duquesa-suite...
# 1    8.4  https://www.booking.com/hotel/es/casa-luz-barc...
# 2    NaN  https://www.booking.com/hotel/es/very-quiet-an...
# 3    8.4  https://www.booking.com/hotel/es/two-barcelona...
# 4    8.1  https://www.booking.com/hotel/es/pereiv.en-gb....
#
#                                          description
# 0  Set the centre of Barcelona, 400 metres from P...
# 1  Set in Barcelona, Sonder Casa Luz offers a ter...
# 2  Very quiet and centric area to enjoy Barcelona...
# 3  Offering a rooftop pool with a large sun terra...
# 4  Pere IV is situated in the Poble Nou District,...

# %%
# Save to csv
#df.to_csv('./data/test_data.csv')

# %% [markdown]
# ## Load data

# %%
Barcelona_period1 = pd.read_csv('barcelona_p1.csv', index_col=0)
Marseille_period1 = pd.read_csv('marseille_p1.csv', index_col=0)
Porto_period1 = pd.read_csv('porto_p1.csv', index_col=0)
Valencia_period1 = pd.read_csv('valencia_p1.csv', index_col=0)


Barcelona_period2 = pd.read_csv('barcelona_p2.csv', index_col=0)
Marseille_period2 = pd.read_csv('marseille_p2.csv', index_col=0)
Porto_period2 = pd.read_csv('porto_p2.csv', index_col=0)
Valencia_period2 = pd.read_csv('valencia_p2.csv' , index_col=0)

# %%
Barcelona_period1.head()
# Out:
#        place  start_date    end_date                                name  \
# 0  Barcelona  2024-02-23  2024-03-03            Duquesa Suites Barcelona
# 1  Barcelona  2024-02-23  2024-03-03                     Sonder Casa Luz
# 2  Barcelona  2024-02-23  2024-03-03                          Valencia 2
# 3  Barcelona  2024-02-23  2024-03-03       Fuster Apartments by Aspasios
# 4  Barcelona  2024-02-23  2024-03-03  BarcelonaForRent The Central Place
#
#      price                                  description_short  rating  \
# 0  € 3,491                                                NaN     8.8
# 1  € 4,457                                                NaN     8.4
# 2  € 1,395                                                NaN     NaN
# 3  € 2,448  Entire apartment • 2 bedrooms • 1 living room ...     9.2
# 4  € 5,350  Entire apartment • 1 bedroom • 1 living room •...     8.5
#
#                                                  url  \
# 0  https://www.booking.com/hotel/es/duquesa-suite...
# 1  https://www.booking.com/hotel/es/casa-luz-barc...
# 2  https://www.booking.com/hotel/es/valencia-2.en...
# 3  https://www.booking.com/hotel/es/fuster-apartm...
# 4  https://www.booking.com/hotel/es/barcelonaforr...
#
#                                          description
# 0  Set the centre of Barcelona, 400 metres from P...
# 1  Set in Barcelona, Sonder Casa Luz offers a ter...
# 2  Located in Barcelona, 1.2 km from Passeig de G...
# 3  Fuster Apartments are just 150 metres from Dia...
# 4  Offering views of Casa Batlló, BarcelonaForRen...

# %%
# Clean the price column

Barcelona_period1['price']= Barcelona_period1['price'].str.replace('€', '').str.replace(',', '')
Barcelona_period1['price'] = Barcelona_period1['price'].astype(int)

# %%
Barcelona_period1.head()
# Out:
#        place  start_date    end_date                                name  \
# 0  Barcelona  2024-02-23  2024-03-03            Duquesa Suites Barcelona
# 1  Barcelona  2024-02-23  2024-03-03                     Sonder Casa Luz
# 2  Barcelona  2024-02-23  2024-03-03                          Valencia 2
# 3  Barcelona  2024-02-23  2024-03-03       Fuster Apartments by Aspasios
# 4  Barcelona  2024-02-23  2024-03-03  BarcelonaForRent The Central Place
#
#    price                                  description_short  rating  \
# 0   3491                                                NaN     8.8
# 1   4457                                                NaN     8.4
# 2   1395                                                NaN     NaN
# 3   2448  Entire apartment • 2 bedrooms • 1 living room ...     9.2
# 4   5350  Entire apartment • 1 bedroom • 1 living room •...     8.5
#
#                                                  url  \
# 0  https://www.booking.com/hotel/es/duquesa-suite...
# 1  https://www.booking.com/hotel/es/casa-luz-barc...
# 2  https://www.booking.com/hotel/es/valencia-2.en...
# 3  https://www.booking.com/hotel/es/fuster-apartm...
# 4  https://www.booking.com/hotel/es/barcelonaforr...
#
#                                          description
# 0  Set the centre of Barcelona, 400 metres from P...
# 1  Set in Barcelona, Sonder Casa Luz offers a ter...
# 2  Located in Barcelona, 1.2 km from Passeig de G...
# 3  Fuster Apartments are just 150 metres from Dia...
# 4  Offering views of Casa Batlló, BarcelonaForRen...
